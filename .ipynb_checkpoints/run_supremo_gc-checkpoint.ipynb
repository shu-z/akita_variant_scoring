# %%
# %cd /home/shu_zhang/SuPreMo/
# Out:
# /home/shu_zhang/SuPreMo
# /home/shu_zhang/miniconda3/envs/supremo_akita_env/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd
main_dir='/home/shu_zhang/SuPreMo/'
data_dir=f'{main_dir}mutate_data/test_data/'
output_dir=f'{main_dir}mutate_data/CTCF_out/'
fa_path='/home/data/genomes/hg38.fa'

# %%
#vcf_name='sv_smallset_nobnd'
vcf_name='CTCF_DEL_20'
vcf_path=f'{data_dir}{vcf_name}.bed'
file_name=f'{vcf_name}_gc_10k'

# %%
vcf_path
# Out:
# '/home/shu_zhang/SuPreMo/mutate_data/test_data/CTCF_DEL_20.bed'

# %%
# !python scripts/SuPreMo.py $vcf_path --file $file_name --dir $output_dir --get_Akita_scores --augment --genome hg38 --fa /home/data/genomes/hg38.fa --nrows 500 --gc_mutate "5000 5000 50"
# Out:
# ['5000', '5000', '50']
# 2024-03-21 19:14:48.402495: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:tensorflow:From /home/shu_zhang/miniconda3/envs/supremo_akita_env/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# ...
