# %%
import pandas as pd

# %%
test1=pd.read_csv('/pollard/data/projects/kgjoni/CBTN_collab/CBTN_data/structural-variants_230620/SVs_all', sep='\t')

# %%
test1
# Out:
#       CHROM        POS                               ID REF  \
# 0      chr1   45396460  MantaBND:10:37221:37237:0:0:0:0   G
# 1      chr1  146965752        MantaDEL:194065:0:1:0:0:0   A
# 2      chr1  242392862    MantaDEL:10:93676:93676:6:0:0   A
# 3      chr2   39239072  MantaBND:10:37221:37237:0:0:0:1   T
# 4      chr2   52165598  MantaBND:10:84279:84280:1:0:0:0   A
# ...     ...        ...                              ...  ..
# 8571  chr22   28005561        MantaINV:145346:0:1:0:0:0   A
# 8572  chr22   30514595      MantaBND:105005:0:1:0:0:0:1   A
# 8573   chrX   11743615        MantaBND:2794:0:1:0:0:0:0   T
# 8574   chrX  119604686       MantaBND:12859:0:1:0:0:0:1   A
# 8575   chrX  147470712         MantaINV:15616:0:1:0:0:0   G
#
#                     ALT QUAL FILTER  \
# 0      ]chr2:39239072]G    .   PASS
# 1                 <DEL>    .   PASS
# 2                 <DEL>    .   PASS
# 3      T[chr1:45396460[    .   PASS
# 4      ]chrX:68905388]A    .   PASS
# ...
